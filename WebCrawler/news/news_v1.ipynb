# %% [markdown]
# # 스포티지 뉴스 단일 크롤링

# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import chromedriver_autoinstaller

# 크롬 드라이버 자동 설치 및 설정
chromedriver_autoinstaller.install()
driver = webdriver.Chrome()

# 기간 설정
START_DATE = "2022.05.03"
END_DATE = "2023.03.03"

# URL 생성
BASE_URL = "https://search.naver.com/search.naver"
QUERY = "스포티지 유압장치 리콜"
params = (
    f"?where=news&query={QUERY}&sm=tab_opt&sort=1&photo=0&field=0&pd=3"
    f"&ds={START_DATE}&de={END_DATE}"
    f"&docid=&related=0&mynews=0&office_type=0&office_section_code=0"
    f"&news_office_checked=&nso=so%3Add%2Cp%3Afrom{START_DATE.replace('.','')}to{END_DATE.replace('.','')}"
    f"&is_sug_officeid=0&office_category=0&service_area=0"
)
url = BASE_URL + params

# 첫 페이지 로드
driver.get(url)
time.sleep(3)  # 페이지 로딩을 기다림

# 데이터를 저장할 리스트
all_data = []

def get_page_data(driver):
    """현재 페이지에서 기사 데이터를 추출하는 함수"""
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    articles = soup.find_all('li', class_='bx')
    data = []

    for article in articles:
        title_tag = article.find('a', class_='news_tit')
        date_tag = article.find('span', class_='info')
        link = title_tag.get('href') if title_tag else None
        
        if title_tag and date_tag:
            title = title_tag.get('title')
            date = date_tag.text.strip()
            data.append({'Title': title, 'Date': date, 'Link': link})
    
    return data

# 스크롤 및 데이터 추출
SCROLL_PAUSE_TIME = 2
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # 데이터 추출
    page_data = get_page_data(driver)
    all_data.extend(page_data)
    
    # 페이지 스크롤
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(SCROLL_PAUSE_TIME)
    
    # 새로운 스크롤 높이 계산
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# 크롤링 완료 후 브라우저 종료
driver.quit()

# 데이터를 DataFrame으로 변환
df = pd.DataFrame(all_data).drop_duplicates().reset_index(drop=True)

# DataFrame 출력
print(df.to_string())  # 전체 데이터를 출력하기 위해 to_string() 사용
# Out:
#                                                                                                                        Title         Date                                                                                                                              Link
# 0                                                                                     리콜車 왜 많지? 1년새 340만대 현대차·기아 각각 100만대 넘어  2023.01.22.                                                                      http://www.smedaily.co.kr/news/articleView.html?idxno=247633
# 1                                                                                           제네시스 GV70·기아 스포티지 리콜...화재 위험 보고돼  2023.01.11.                                                                     https://daily.hankooki.com/news/articleView.html?idxno=913468
# 2                                                                          [현대차·기아 대규모 리콜] 車 제동장치 제어 전자장비 화재 위험…“충돌 없이도 불난다”  2022.11.28.                                                        http://economychosun.com/client/news/view.php?boardName=C05&t_num=13613807
# 3   "Possibility of a fire in conditions of no engine start or no collision?" Hyundai·Kia Motors recalled 1.8 million vehicl  2022.11.21.                                                                         http://www.kdfnews.com/news/articleView.html?idxno=100292
# 4                                                                                            [단독] 현대차·기아, 화재위험 韓·美에서 수백만대 리콜  2022.11.20.  https://biz.chosun.com/industry/car/2022/11/20/WDSL42VWIZGMNOMEMZMYF7GKUM/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 5                                                                                              현대·기아·테슬라·벤츠 등 35개 차종 50만대 리콜  2022.10.28.                                                                 http://www.businesskorea.co.kr/news/articleView.html?idxno=103067
# 6                                                                                             제작결함 발견된 현대·기아·테슬라·벤츠 등 자발적 리콜  2022.10.28.                                                                          http://www.dailypop.kr/news/articleView.html?idxno=63820
# 7                                                                                   기아 구형 스포티지, 엔진화재 우려로 외부 주차 권고. 7만1천여대 리콜  2022.10.28.                                                                    https://www.autodaily.co.kr/news/articleView.html?idxno=500792
# 8                                                                                            현대차·기아 43만여대 리콜, 테슬라 4만여대도 시정조치       E3면 1단                                                                                       https://www.joongang.co.kr/article/25112868
# 9                                                                                               현대차 싼타페·기아 스포티지·테슬라 모델3 등 리콜  2022.10.27.                            http://autotimes.hankyung.com/apps/news.sub_view?popup=0&nid=03&c1=03&c2=03&c3=00&nkey=202210272046141
# 10                                                                                               현대·기아·테슬라·벤츠 등 자발적 시정조치(리콜)  2022.10.27.                                                                              https://www.ktv.go.kr/content/view?content_id=659877
# 11                                                                                         기아, 美서 구형 스포티지 7만1000대 리콜…“화재 위험”  2022.10.27.                                                     http://www.segye.com/content/html/2022/10/27/20221027516812.html?OutUrl=naver
# 12                                                                                    기아, 한국 이어 미국서도 대규모 리콜..북미형 스포티지 7만대 이상  2022.10.27.                                                                http://www.dailycar.co.kr/content/news.html?type=view&autoId=46176
# 13                                                                                          국토부, 현대차·기아·테슬라·벤츠 등 49만3152대 리콜  2022.10.27.                                                                       https://www.khan.co.kr/economy/auto/article/202210271633001
# 14                                                                                         국토부, 현대차·기아·테슬라·벤츠 등 리콜..49만대 이상!  2022.10.27.                                                                http://www.dailycar.co.kr/content/news.html?type=view&autoId=46174
# 15                                                                                                 기아 스포티지 '화재 위험' 대규모 리콜 단행  2022.10.27.                                                                     http://www.safetimes.co.kr/news/articleView.html?idxno=115399
# 16                                                                                    '합선 화재·SW 오류'…테슬라·현대차·벤츠 등 49만3152대 리콜  2022.10.27.                                                                                                  http://kbench.com/?q=node/238431
# 17                                                                                           국토부, 테슬라·폭스바겐·현대차 등 49만3000대 리콜  2022.10.27.                                                                        https://www.cstimes.com/news/articleView.html?idxno=517190
# 18                                                                                     현대·기아·테슬라·벤츠 등 6개사 35개 차종 49만여대 리콜 실시  2022.10.27.                                                                         http://www.queen.co.kr/news/articleView.html?idxno=382074
# 19                                                                                   스포티지·투싼 화재 위험…35개 차종 493,152대 제작결함 '리콜'  2022.10.27.                                                                       http://www.newsroad.co.kr/news/articleView.html?idxno=20649
# 20                                                                                                       스포티지와 쏘렌토 등 49만대 리콜  2022.10.27.                                                                       https://news.bbsi.co.kr/news/articleView.html?idxno=3086109
# 21                                                                                                테슬라, 현대차, 벤츠 등 49만3152대 리콜  2022.10.27.                                                                           http://www.wsobi.com/news/articleView.html?idxno=179513
# 22                                                                                                     화재 발생 가능성에 기아 스포티지 리콜  2022.10.27.                                                         https://news.koreadaily.com/2022/10/26/economy/car/20221026200358057.html
# 23                                                                                    스포티지 투산 테슬라 제작결함으로 무더기 리콜, 6개 차종 49만 대  2022.10.27.                                                                 https://www.businesspost.co.kr/BP?command=article_view&num=296474
# 24                                                                                                  스포티지·소렌토·테슬라 등 49만대 '리콜'  2022.10.27.                                                                 http://www.smartcitytoday.co.kr/news/articleView.html?idxno=24960
# 25                                                                                                   기아, 美서 구형 스포티지 7.1만대 리콜  2022.10.27.                                                                              http://www.m-i.kr/news/articleView.html?idxno=959918
# 26                                                                                 현대차·테슬라·벤츠 등 6개사 49만3152대 리콜… "화재·사고 가능성"  2022.10.27.                                                                       http://www.seoulwire.com/news/articleView.html?idxno=484691
# 27                                                                                                 스포티지·투싼, 전자제어 유압장치 불량에 리콜  2022.10.27.                                                                https://www.busan.com/view/busan/view.php?code=2022102710552759866
# 28                                                                                       현대차·기아의 투산‧스포티지 18만대 '화재 발생 가능성' 리콜  2022.10.27.                                                                     http://www.seouleconews.com/news/articleView.html?idxno=68870
# 29                                                                                            현대·기아·테슬라·벤츠 등 35개 차종 49만여대 리콜  2022.10.27.                                                                       http://www.namdonews.com/news/articleView.html?idxno=700568
# 30                                                                                            현대차·기아·테슬라·벤츠·폭스바겐 등 35개 차종 리콜  2022.10.27.                                                                       http://www.sporbiz.co.kr/news/articleView.html?idxno=636068
# 31                                                                                            현대·기아·테슬라·벤츠 등 35개 차종 결함 발견 리콜  2022.10.27.                                                                          http://www.kdfnews.com/news/articleView.html?idxno=98957
# 32                                                                                                스포티지 화재 가능성…35개 차종 49만대 리콜  2022.10.27.                                                                   http://www.enewstoday.co.kr/news/articleView.html?idxno=1609729
# 33                                                                                                   국토부, 현대·기아·테슬라 등 6개사 리콜  2022.10.27.                                                                          http://www.finomy.com/news/articleView.html?idxno=119540
# 34                                                                                      기아 스포티지 전자유압장치-테슬라 모델3 등 49만3152대 리콜  2022.10.27.                                                                          http://www.gpkorea.com/news/articleView.html?idxno=93893
# 35                                                                                           '전자유압장치 합선 가능성' 스포티지·투싼 18만대 리콜  2022.10.27.                                                                         http://www.newsfc.co.kr/news/articleView.html?idxno=54948
# 36                                                                                        스포티지·투싼, 전자제어 유압장치 화재발생 가능성으로 '리콜'  2022.10.27.                                                                         http://www.bizwnews.com/news/articleView.html?idxno=44165
# 37                                                                               국토부, 현대차·기아·테슬라 등 49만여대 리콜…"내부 합선으로 화재 가능성"  2022.10.27.                                                                             http://www.4th.kr/news/articleView.html?idxno=2027291
# 38                                                                               '화재·상해 가능성' 스포티지·싼타페 등 35개 차종 49만여대 제작결함 리콜  2022.10.27.                                                                     http://www.daejonilbo.com/news/articleView.html?idxno=2030205
# 39                                                                                                  현대·기아·테슬라·벤츠 49만대 자발적 리콜  2022.10.27.                                                       https://www.seoul.co.kr/news/newsView.php?id=20221027500022&wlog_tag3=naver
# 40                                                                                "과징금 부과"…국토부, 테슬라 모델3·폭스바겐 투아렉 안전기준 부적합 리콜  2022.10.27.                                                           http://www.dizzotv.com/site/data/html_dir/2022/10/27/2022102780026.html
# 41                                                                                            현대·기아·테슬라·벤츠 등 35개 차종 49만여대 리콜  2022.10.27.                                                                          https://www.youthdaily.co.kr/news/article.html?no=114114
# 42                                                                                      현대차부터 벤츠·테슬라까지… 35개 차종 49만3152대 `리콜`       10면 1단                                                     http://www.dt.co.kr/contents.html?article_no=2022102702109932064002&ref=naver
# 43                                                                                     스포티지·투싼 17만여대 합선 가능성… 테슬라 등 35개 차종 리콜  2022.10.27.                                                            https://it.chosun.com/site/data/html_dir/2022/10/27/2022102700838.html
# 44                                                                                       합선·변속기 오류·창틀 불량…현대·테슬라·벤츠 등 49만대 리콜  2022.10.27.                                                                                  http://www.kukinews.com/newsView/kuk202210270010
# 45                                                                                      기아 스포티지·테슬라 모델3 등 35개 차종 49만3152대 리콜  2022.10.27.                                                                     https://daily.hankooki.com/news/articleView.html?idxno=886597
# 46                                                                                    국토부, '합선 가능성' 스포티지·투싼 등 35개 차종 49만대 리콜  2022.10.27.                                                   http://tbs.seoul.kr/news/newsView.do?typ_800=3&idx_800=3481490&seq_800=20474167
# 47                                                                                          기아 구형 스포티지, '화재 위험'… 美서 7.1만대 리콜  2022.10.27.                                                                     http://moneys.mt.co.kr/news/mwView.php?no=2022102708010464795
# 48                                                                                            현대차·기아·테슬라·벤츠 등 결함 차량 49만여대 리콜  2022.10.27.                                                         https://economist.co.kr/2022/10/27/industry/normal/20221027074334825.html
# 49                                                                                        스포티지·투싼 등 35개 차종 49만여대 리콜…"합선 가능성"  2022.10.27.                                                                      https://biz.sbs.co.kr/article_hub/20000086451?division=NAVER
# 50                                                                                               현대·기아·테슬라·벤츠 등 무더기 시정조치(리콜)  2022.10.27.                                              http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0200&key=20221027.99099007337
# 51                                                                                              스포티지·투싼·모델3 등 35개 차종 49만대 리콜  2022.10.27.                                                          http://www.wowtv.co.kr/NewsCenter/News/Read?articleId=A202210270017&t=NN
# 52                                                                                             기아, 화재 위험에 美서 '스포티지' 7만1천대 리콜  2022.10.27.                                                                      https://biz.sbs.co.kr/article_hub/20000086428?division=NAVER
# 53                                                                                            유압장치 화재 가능성 스포티지 9만대 등 49만대 리콜  2022.10.27.                                                                                          https://www.nocutnews.co.kr/news/5839413
# 54                                                                                             '화재발생 우려' 스포티지·투싼 17만대 무더기 리콜  2022.10.27.                                                                       http://www.newstomato.com/ReadNews.aspx?no=1155767&inflow=N
# 55                                                                                       현대·기아·테슬라·벤츠 등 35개 차종 49만 3,152대 리콜  2022.10.27.                                                                             https://news.kbs.co.kr/news/view.do?ncd=5587836&ref=A
# 56                                                                                               테슬라 모델3 등 파워윈도 SW 오류…자발적 리콜  2022.10.27.                                                                                       https://zdnet.co.kr/view/?no=20221027052104
# 57                                                                                        '합선 가능성' 스포티지·투싼 등 35개 차종 49만여대 리콜  2022.10.27.                                                                       https://www.yna.co.kr/view/AKR20221026147600003?input=1195m
# 58                                                                                         스포티지·투싼·벤츠 C200·C300, ‘화재 가능성’ 리콜  2022.10.27.  https://biz.chosun.com/industry/car/2022/10/27/WBRFWSXEKFCN7ERFNP2LOQHXIM/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 59                                                                                             기아 스포티지·테슬라 모델3 등 49만3152대 리콜  2022.10.27.                                                        http://www.newsis.com/view/?id=NISX20221026_0002062507&cID=10401&pID=10400
# 60                                                                                쏘렌토는 변속기 제어 오류, 벤츠는 부품 이탈… 6개사 49.3만대 車 리콜  2022.10.27.                                                                     http://moneys.mt.co.kr/news/mwView.php?no=2022102619332540649
# 61                                                                                         스포티지·쏘렌토·싼타페·니로…현대·기아차 43만대 리콜 실시  2022.10.27.                                                                                       https://www.joongang.co.kr/article/25112600
# 62                                                                                            현대·테슬라·벤츠 등 6개사, 제작결함 49만여대 리콜  2022.10.27.                                                                              https://view.asiae.co.kr/article/2022102700284507884
# 63                                                                                     현대·기아·테슬라·벤츠 등 6개사 35개 차종 49만여대 리콜 실시  2022.10.27.                                                                                             https://www.news1.kr/articles/4844942
# 64                                                                                        기아, 미국서 스포티지 7만1000대 리콜…"화재 발생 위험"  2022.10.27.                                                                     https://hankookilbo.com/News/Read/A2022102700070003427?did=NA
# 65                                                                                   기아, 미국서 스포티지 7만1000대 자발적 리콜…이유는 “화재 위험”  2022.10.26.                                                                                        https://www.etoday.co.kr/news/view/2186104
# 66                                                                                      기아, 美서 구형 스포티지 7만1000대 리콜…"화재 발생 위험"  2022.10.26.                                                                                       https://www.joongang.co.kr/article/25112479
# 67                                                                                                기아차, 미국에서 스포티지 7.1만대 리콜 결정  2022.10.26.                                                                http://www.edaily.co.kr/news/newspath.asp?newsid=04385366632496856
# 68                                                                                           "화재 위험"…기아, 美서 구형 스포티지 7만1천대 리콜  2022.10.26.                                                          http://www.wowtv.co.kr/NewsCenter/News/Read?articleId=A202210260339&t=NN
# 69                                                                                        기아, 미국서 스포티지 7만1000대 리콜… 화재 발생 가능성  2022.10.26.  https://biz.chosun.com/industry/car/2022/10/26/4AYGDR5C6RAJJEB6DBY5HTJTIE/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 70                                                                                      '차량 화재 위험'…기아, 美서 구형 스포티지 7만1000대 리콜  2022.10.26.                                                                              https://view.asiae.co.kr/article/2022102621453948687
# 71                                                                                         기아, 美서 구형 스포티지 7만1000대 리콜…"화재 위험"  2022.10.26.                                                                             http://news.heraldcorp.com/view.php?ud=20221026000780
# 72                                                                                           기아, 美서 구형 스포티지 7만1천대 리콜…"화재 위험"  2022.10.26.                                                                       https://www.yna.co.kr/view/AKR20221026172000009?input=1195m

# %%
# 데이터 저장
df.to_excel('/Users/admin/softeer/week5/스포티지뉴스.xlsx', index=False)
print("데이터가 'titles_and_dates.csv' 파일에 저장되었습니다.")
# Out:
# 데이터가 'titles_and_dates.csv' 파일에 저장되었습니다.

# %%
df
# Out:
#                                                 Title         Date  \
# 0              리콜車 왜 많지? 1년새 340만대 현대차·기아 각각 100만대 넘어  2023.01.22.
# 1                    제네시스 GV70·기아 스포티지 리콜...화재 위험 보고돼  2023.01.11.
# 2   [현대차·기아 대규모 리콜] 車 제동장치 제어 전자장비 화재 위험…“충돌 없이도 불난다”  2022.11.28.
# 3   "Possibility of a fire in conditions of no eng...  2022.11.21.
# 4                     [단독] 현대차·기아, 화재위험 韓·美에서 수백만대 리콜  2022.11.20.
# ..                                                ...          ...
# 68                    "화재 위험"…기아, 美서 구형 스포티지 7만1천대 리콜  2022.10.26.
# 69                 기아, 미국서 스포티지 7만1000대 리콜… 화재 발생 가능성  2022.10.26.
# 70               '차량 화재 위험'…기아, 美서 구형 스포티지 7만1000대 리콜  2022.10.26.
# 71                  기아, 美서 구형 스포티지 7만1000대 리콜…"화재 위험"  2022.10.26.
# 72                    기아, 美서 구형 스포티지 7만1천대 리콜…"화재 위험"  2022.10.26.
#
#                                                  Link
# 0   http://www.smedaily.co.kr/news/articleView.htm...
# 1   https://daily.hankooki.com/news/articleView.ht...
# 2   http://economychosun.com/client/news/view.php?...
# 3   http://www.kdfnews.com/news/articleView.html?i...
# 4   https://biz.chosun.com/industry/car/2022/11/20...
# ..                                                ...
# 68  http://www.wowtv.co.kr/NewsCenter/News/Read?ar...
# 69  https://biz.chosun.com/industry/car/2022/10/26...
# 70  https://view.asiae.co.kr/article/2022102621453...
# 71  http://news.heraldcorp.com/view.php?ud=2022102...
# 72  https://www.yna.co.kr/view/AKR2022102617200000...
#
# [73 rows x 3 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup
import pandas as pd
import chromedriver_autoinstaller
from datetime import datetime, timedelta

# 크롬 드라이버 자동 설치 및 설정
chromedriver_autoinstaller.install()
driver = webdriver.Chrome()

# 예시 데이터베이스 불러오기
# data = {
#     "Ministry": ["국토교통부", "환경부", "국토교통부", "국토교통부", "국토교통부", "국토교통부", "국토교통부", "국토교통부", "국토교통부", "국토교통부", "환경부", "국토교통부"],
#     "Date": ["2016-12-09", "2017-07-19", "2019-06-10", "2024-07-03", "2023-01-04", "2022-10-31", "2021-05-31", "2022-10-06", "2017-06-16", "2017-05-22", "2019-09-27", "2017-01-20"],
#     "Company": ["기아", "기아", "기아", "기아", "기아", "기아", "기아", "기아", "기아", "기아", "기아", "기아"],
#     "Model": ["구형 스포티지(KM)", "스포티지 2.0 디젤", "스포티지(QL)", "스포티지", "스포티지", "스포티지", "스포티지 등 2차종", "스포티지", "구형 쏘렌토, 카니발, 스포티지", "K5, K7, 스포티지", "스포티지", "스포티지"],
#     "Issue": ["ESC 관련 리콜", "DPF 관련 리콜", "조향장치 관련 리콜", "전자제어유압장치(HECU) 관련 리콜", "전자제어유압장치(HECU) 관련 리콜", "전자제어유압장치 관련 리콜", "전자제어유압장치 관련 리콜", "전기배선 관련 리콜", "연료공급호스 관련 리콜", "세타2엔진<GDI>관련 리콜", "매연 포집 필터(DPF) / 엔진제어장치(ECU) 관련 리콜", "리어 트레일링암 관련 리콜"]
#}

# 날짜 형식 변환
df['Date'] = pd.to_datetime(df['Date'])

# 기간 설정 함수
def get_date_range(date):
    start_date = date - timedelta(days=90)
    end_date = date + timedelta(days=90)
    return start_date.strftime("%Y.%m.%d"), end_date.strftime("%Y.%m.%d")

# 페이지 스크롤 및 데이터 추출 함수
def get_page_data(driver):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    articles = soup.find_all('li', class_='bx')
    data = []

    for article in articles:
        title_tag = article.find('a', class_='news_tit')
        date_tag = article.find('span', class_='info')
        link_tag = title_tag.get('href') if title_tag else None
        
        if title_tag and date_tag:
            title = title_tag.get('title')
            date = date_tag.text.strip()
            link = link_tag.strip()
            data.append({'Title': title, 'Date': date, 'Link': link})
    
    return data

# 각 항목에 대해 크롤링 수행
for index, row in df.iterrows():
    model = row['Model']
    issue = row['Issue']
    date = row['Date']
    
    start_date, end_date = get_date_range(date)
    query = f"{model} {issue}"
    
    # URL 생성
    base_url = "https://search.naver.com/search.naver"
    params = f"?where=news&query={query}&sm=tab_opt&sort=1&photo=0&field=0&pd=3&ds={start_date}&de={end_date}&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Afrom{start_date.replace('.','')}to{end_date.replace('.','')}&is_sug_officeid=0&office_category=0&service_area=0"
    url = base_url + params

    # 첫 페이지 로드
    driver.get(url)
    time.sleep(3)  # 페이지 로딩을 기다림

    # 데이터를 저장할 리스트
    all_data = []

    # 스크롤 및 데이터 추출
    
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # 데이터 추출
        page_data = get_page_data(driver)
        all_data.extend(page_data)
        
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        # Wait to load page
        time.sleep(2)
        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    # 데이터를 DataFrame으로 변환
    result_df = pd.DataFrame(all_data).drop_duplicates().reset_index(drop=True)

    # 파일 이름 생성
    model_cleaned = model.replace("/", "").replace(" ", "_").replace("(", "").replace(")", "")
    issue_cleaned = issue.replace("/", "").replace(" ", "_").replace("(", "").replace(")", "")
    date_str = date.strftime("%Y%m%d")
    file_name = f"/Users/admin/softeer/project/스포티지뉴스/{model_cleaned}_{issue_cleaned}_{date_str}.xlsx"

    # DataFrame을 엑셀 파일로 저장
    result_df.to_excel(file_name, index=False)
    print(f"데이터가 '{file_name}' 파일에 저장되었습니다.")

# 크롤링 완료 후 브라우저 종료
driver.quit()
